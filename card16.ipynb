# %% [markdown]
# # Prática: Docker e Containers para Aplicações (III)

# %% [markdown]
# ## Seção 1 - Instalando Docker no Linux
#
# ![image.png](attachment:2ec29167-1a00-4a7b-8ae3-293dc8bd2e02.png)

# %% [markdown]
# ## Seção 2 - Docker CLI
# ![image.png](attachment:802f8529-69cf-4406-9ff2-9c6eca04e781.png)
# ### Criando um container
# ![image.png](attachment:6f20f233-0241-4493-b999-dbe5b9c6d682.png)
# ### Remover um container
# ![image.png](attachment:3e0add04-69fe-4432-a1d9-c027882d373c.png)

# %% [markdown]
# ## Seção 3 - Manipulando Docker Container Através da Docker CLI
# ### Criando um container teste iterativo com terminal, imagem alpine com shell
# ![image.png](attachment:9981d9c3-ddcf-4f82-9efe-d9cea27e63ee.png)
# ### Inicializando o container
# ![image.png](attachment:1042f1e0-ff93-4c87-923c-1631bac40638.png)
# ### Interagindo com o container
# ![image.png](attachment:2ed795e6-a404-4215-8fb5-2497e5bbfdd7.png)
# ### ls no container
# ![image.png](attachment:848a3778-1dca-4c4a-8b4d-375b75683189.png)
# ### Atalho para inicializar o container
# ![image.png](attachment:8d4c7f55-5da5-488e-9e69-619ba67fee6c.png)
# ### Manipulando arquivos dentro do container
# ![image.png](attachment:4788f931-fb2d-4748-932d-ba5db0ddc489.png)
# ### Mapeando volumes - Salvando estado de um container
# ![image.png](attachment:b4132cbd-3fdd-48cb-97db-79781c0b0f69.png)
# #### cuidar para não deletar tudo na máquina hospedeira.
# ### Mapeando portas
# #### As portas expostas no processo de construção de imagem docker podem ser mapeadas para uma porta específica do hospedeiro.
# ![image.png](attachment:f2309a2e-d5de-47e1-b37c-e1c9f9e5d09e.png)
# ### Docker inspect
# ![image.png](attachment:7a3a2a78-d2e5-471e-84b7-bf403e4a81d8.png)
# ### Acessando o ip no navegador
# ![image.png](attachment:d380051b-11f9-408f-9142-8f6c8687d020.png)
# ### Route e rede criada pelo docker
# ![image.png](attachment:5079e979-5780-4afb-af40-9e9192cb3e28.png)
# ### Expondo portas para que outras máquinas tenham acesso
# ![image.png](attachment:a52940ae-15ac-42a9-8794-0909d4f1c3dc.png)
# ![image.png](attachment:b3518883-0afd-4378-ad5f-3c6899e93d44.png)

# %% [markdown]
# ## Seção 4 - Manipulando Imagens Docker atraés de CLI
# ### Conceito de imagem, gerando uma imagem a partir de um container
# #### Imagens e Containers
# ![image.png](attachment:9a8bf701-65dd-4fe6-afce-f7c8ff8e972a.png)
# ### Exportando imagens para arquivos .tar
# ![image.png](attachment:503a816f-e28c-406d-a839-37ab1f5af0e7.png)
# ![image.png](attachment:a822f5c6-764f-4585-b234-f460c1354545.png)
# ![image.png](attachment:5f02a247-665f-412e-bd6e-9791ee19eee1.png)
# ### Consultando Histórico de uma imagem
# ![image.png](attachment:d01d3ce9-cdb1-42f3-bae7-309f7f4e3aa7.png)
# ### Importando Imagens a partir de tar files
# ![image.png](attachment:c3ea4577-847f-49a2-acc4-b7965fde66cd.png)
# ![image.png](attachment:fe94f384-ad2d-40e9-85f1-85fb4a4118fe.png)
# ### Demais comandos do objeto image (inspect, prune, pull, tag e push)
# ![image.png](attachment:360d2821-5bfb-4bff-977f-63d096db09ea.png)
# ![image.png](attachment:1d9ea57a-60be-46b6-a97e-c3293a1d83be.png)

# %% [markdown]
# ## Seção 5 - Construindo imagens com docker build
# ![image.png](attachment:55a3b419-9365-44f2-bd5f-77e28a0a54ac.png)
# ![image.png](attachment:f8d952f0-522c-484e-881e-017bce031b9a.png)

# %% [markdown]
# ## Seção 6 - Volumes - Salvando o estado dos containers atraves de volumes
# São utilizados para salvar o estado do container, basicamente um ponto de montagem localizado fora do sistema de arquivos do container.
# Permite mapear diretórios da máquina hospedeira no container.
# Criar compartilhamento de informações entre containers.
# ![image.png](attachment:a8a27347-dabf-4ec3-b613-dfaafc9d64b1.png)
# ![image.png](attachment:fbaa9093-8d98-43f9-b25b-af57ed4a97de.png)
# ![image.png](attachment:b77380ca-7ec1-4829-8161-e96f53fcd382.png)

# %% [markdown]
# ## Seção 7 - Introdução ao comando Docker System
# ### System: Alguns comandos para a administração da Docker Engine
# ![image.png](attachment:0c17763b-2a0b-4a8b-aca7-1acba61e407a.png)
# ![image.png](attachment:12001345-a556-46be-b394-2808abd6f443.png)
# ![image.png](attachment:9c19af94-759b-4a16-831f-f01af542f17a.png)
# ![image.png](attachment:438064a3-3048-42d9-bce1-8503ad73ec73.png)

# %% [markdown]
# ## Seção 8 - Exercicio
# 1. ![image.png](attachment:4a41b94c-67d7-4c34-99d5-dc1e2b6bffd5.png)![image.png]
# 2.![image.png](attachment:4078d170-18ec-4302-a3d2-4b44a9e01a76.png)
# ![image.png](attachment:8935ba78-3a7b-4047-bf1c-c20bfd242be7.png)
# ![image.png](attachment:1d619f96-eedc-458a-b4e6-53477a710911.png)
# ![image.png](attachment:614cc8ca-6c3f-4a06-9837-aa42201a1382.png)
# ![image.png](attachment:a23e5bd7-09eb-485e-9768-e62a231e3649.png)
